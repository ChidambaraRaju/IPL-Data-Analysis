# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Udemy Course - Python Bootcamp\\Project'

# %%
cd D:\Study\Python\Python Course\Notes\Data for IPL analysis
# Out:
# D:\Study\Python\Python Course\Notes\Data for IPL analysis

# %%
data = pd.read_csv("IPLData.csv")

# %%
data.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# ...

# %%
data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
data.isna().sum() #provides the sum of all null values
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %%
# segregating the data of capped batters
batters = data.loc[(data["Player_Type"]) == "Batter"]
batters_new = batters.loc[(batters["Capped"]) == 1]
capped_batters = batters_new[["Player Name","Team", "Nationality", "Matches_Played","Runs", "Average", "Strike_Rate"]]

# %%
capped_batters.head(10)
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1      Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3     Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4    Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
# 5      Robin Uthappa    Chenai       Indian           193.0  4722.0    27.94
# 6          Jason Roy    Gujarat    Overseas            13.0   329.0    29.91
# 7   Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 8        Priyam Garg  Hyderabad      Indian            19.0   205.0    14.64
# 12    Rahul Tripathi  Hyderabad      Indian            62.0  1385.0    26.13
#
#     Strike_Rate
# 0        126.60
# 1        123.96
# 2        131.09
# 3        121.83
# 4        151.17
# 5        130.15
# ...

# %%
# segregating the data of capped bowlers
bowlers = data.loc[(data["Player_Type"]) == "Bowler "]
bowlers_new = bowlers.loc[(bowlers["Capped"]) == 1]
capped_bowlers = bowlers_new[["Player Name","Team", "Nationality", "Matches_Played","Wickets", "Bowling_average","Economy","Bowling_Strike_Rate"]]
capped_bowlers.head(10)
# Out:
#           Player Name       Team Nationality  Matches_Played  Wickets  \
# 36     Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37       Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38    Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39        T Natarajan  Hyderabad      Indian            24.0     20.0
# 40     Deepak Chahar     Chennai      Indian            63.0     59.0
# 41   Prasidh Krishna   Rajasthan      Indian            34.0     30.0
# 42    Lockei Ferguson    Gujarat    Overseas            22.0     24.0
# 43    Josh Hazlewood   Bangalore    Overseas            12.0     12.0
# 45  Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 46    Shardul Thakur       Delhi      Indian            61.0     67.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# ...

# %%
# segregating the data of capped keepers
keepers = data.loc[(data["Player_Type"]) == "Keeper"]
keepers_new = keepers.loc[(keepers["Capped"]) == 1]
capped_keepers = keepers_new[["Player Name","Team", "Nationality", "Matches_Played","Runs", "Average", "Strike_Rate","Catches","Run_outs","Stumps"]]
capped_keepers.head(10)
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
#
#      Average  Strike_Rate  Catches  Run_outs  Stumps
# 105     31.3        130.9     53.0       0.0    14.0
# 106     29.4        127.5     58.0      12.0     2.0
# ...

# %%
# segregating the data of capped allrounders
allrounders = data.loc[(data["Player_Type"]) == "Allrounder"]
allrounders_new = allrounders.loc[(allrounders["Capped"]) == 1]
capped_allrounders = allrounders_new[["Player Name","Team", "Nationality", "Matches_Played","Runs", "Average", "Strike_Rate","Wickets", "Bowling_average","Economy","Bowling_Strike_Rate"]]
capped_allrounders.head(10)
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# ...

# %%
# making the NAN values as 0
capped_batters=capped_batters.fillna(0)
capped_bowlers=capped_bowlers.fillna(0)
capped_keepers=capped_keepers.fillna(0)
capped_allrounders=capped_allrounders.fillna(0)

# %%
# checking null values in the data
print(capped_batters.isnull().sum())
print(capped_bowlers.isnull().sum())
print(capped_keepers.isnull().sum())
print(capped_allrounders.isnull().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %%
# Analysing the Batters Data

top_batters = capped_batters.loc[capped_batters["Average"]>=32.0]

top_batters_average = top_batters.sort_values('Average', ascending=False)
top_batters_runs = top_batters.sort_values('Runs', ascending=False)
top_batters_matches = top_batters.sort_values('Matches_Played', ascending=False)
top_batters_strike_rate = top_batters.sort_values('Strike_Rate', ascending=False)

# %%
top_batters_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
top_batters_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# From the analysis the top three batters will be:
# 1. David Warner
# 2. KL Rahul
# 3. Virat Kohli

# %%
top_bowlers = capped_bowlers.loc[capped_bowlers['Bowling_average']<=24]
top_bowlers_matches_played = top_bowlers.sort_values('Matches_Played',ascending=False)
top_bowlers_wickets = top_bowlers.sort_values('Wickets',ascending=False)
top_bowlers_bowling_average = top_bowlers.sort_values('Bowling_average')
top_bowlers_Economy = top_bowlers.sort_values('Economy')
top_bowlers_bowling_Strike_Rate = top_bowlers.sort_values('Bowling_Strike_Rate')

# %%
top_bowlers_bowling_average
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_bowling_Strike_Rate
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_matches_played
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
top_bowlers_wickets
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
top_bowlers_Economy
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %% [markdown]
# From the above analysis the top 4 bowlers will be:
# 1. Jasprit Bumrah
# 2. Kagiso Rabada
# 3. Yuzvendra Chahal
# 4. Nathan Coulter-Nile

# %%
# Analysing the all rounders data
top_allrounders = capped_allrounders.loc[capped_allrounders['Strike_Rate']>=140]

top_allrounders_matches_played = top_allrounders.sort_values('Matches_Played',ascending=False)
top_allrounders_runs = top_allrounders.sort_values('Runs',ascending=False)
top_allrounders_average = top_allrounders.sort_values('Average',ascending=False)
top_allrounders_strike_rate = top_allrounders.sort_values('Strike_Rate',ascending=False)

top_allrounders_wickets = top_allrounders.sort_values('Wickets',ascending=False)
top_allrounders_bowling_average = top_allrounders.sort_values('Bowling_average')
top_allrounders_economy = top_allrounders.sort_values('Economy')
top_allrounders_bowling_strike_rate = top_allrounders.sort_values('Bowling_Strike_Rate')

# %%
top_allrounders_matches_played
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounders_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounders_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounders_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
top_allrounders_wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrounders_bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
top_allrounders_economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
#
# ...

# %%
top_allrounders_bowling_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %% [markdown]
# From the above analysis the top all rounders are:
# 1. Andre Russell
# 2. Hardik Pandya
# 3. Sunil Narine
# 4. Jofra Archer

# %%
# Analyzing the keepers data

top_keepers = capped_keepers.loc[capped_keepers['Average']>=25]
top_keepers_matches_played = top_keepers.sort_values('Matches_Played',ascending=False)
top_keepers_runs = top_keepers.sort_values('Runs',ascending=False)
top_keepers_average = top_keepers.sort_values('Average',ascending=False)
top_keepers_strike_rate = top_keepers.sort_values('Strike_Rate',ascending=False)
top_keepers_catches = top_keepers.sort_values('Catches',ascending=False)
top_keepers_run_outs = top_keepers.sort_values('Run_outs',ascending=False)
top_keepers_stumps = top_keepers.sort_values('Stumps',ascending=False)

# %%
top_keepers_matches_played
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
top_keepers_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
top_keepers_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_run_outs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %% [markdown]
# From the above analysis the top three wicket keepers are:
# 1. MS Dhoni
# 2. Dinesh Karthik
# 3. Rishabh Pant

# %% [markdown]
# # Visual representation:

# %% [markdown]
# # Visualization of Batters data:

# %%
# plot for top batters strike rate
sns.set(font_scale=1.5) # to increase font size
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_batters,palette="husl")
plt.ylabel('Strike Rate')
plt.title('Top Batsmans vs Strike Rate')
# Out:
# Text(0.5, 1.0, 'Top Batsmans vs Strike Rate')

# %%
sns.set(font_scale=1.5) # to increase font size
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Runs',data=top_batters,palette='BrBG')
plt.ylabel('Runs')
plt.title('Top Batsmans vs Runs')
# Out:
# Text(0.5, 1.0, 'Top Batsmans vs Runs')

# %%
sns.set(font_scale=1.5) # to increase font size
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Average',data=top_batters,palette='Reds')
plt.ylabel('Average')
plt.title('Top Batsmans vs Average')
# Out:
# Text(0.5, 1.0, 'Top Batsmans vs Average')

# %%
sns.set(font_scale=1.5) # to increase font size
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_batters,palette='Greens')
plt.ylabel('Matches Played')
plt.title('Top Batsmans vs Matches Played')
# Out:
# Text(0.5, 1.0, 'Top Batsmans vs Matches Played')

# %% [markdown]
# # Visualization of Bowlers data:

# %%
sns.set(font_scale=1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_bowlers,palette='husl')
plt.ylabel('Matches Played')
sns.set(font_scale=1.5)
plt.title('Top Bowlers vs Matches Played')
# Out:
# Text(0.5, 1.0, 'Top Bowlers vs Matches Played')

# %%
sns.set(font_scale=1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Wickets',data=top_bowlers)
sns.set(font_scale=1.5)
plt.ylabel('Wickets')
plt.title('Top Bowlers vs Wickets')
# Out:
# Text(0.5, 1.0, 'Top Bowlers vs Wickets')

# %%
sns.set(font_scale=1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_bowlers,palette='Blues')
plt.ylabel('Bowling Average')
sns.set(font_scale=1.5)
plt.title('Top Bowlers vs Bowling Average')
# Out:
# Text(0.5, 1.0, 'Top Bowlers vs Bowling Average')

# %%
sns.set(font_scale=1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Economy',data=top_bowlers,palette='Oranges')
plt.ylabel('Economy')
sns.set(font_scale=1.5)
plt.title('Top Bowlers vs Economy')
# Out:
# Text(0.5, 1.0, 'Top Bowlers vs Economy')

# %%
sns.set(font_scale=1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_bowlers)
plt.ylabel('Bowling Strike Rate')
sns.set(font_scale=1.5)
plt.title('Top Bowlers vs Bowling Strike Rate')
# Out:
# Text(0.5, 1.0, 'Top Bowlers vs Bowling Strike Rate')

# %% [markdown]
# # Visualization of All Rounders Data:

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_allrounders)
plt.ylabel('Matches Played')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Matches Played')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Matches Played')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Runs',data=top_allrounders)
plt.ylabel('Runs')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Runs')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Runs')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Average',data=top_allrounders)
plt.ylabel('Average')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Average')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Average')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_allrounders)
plt.ylabel('Strike Rate')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Strike Rate')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Strike Rate')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Wickets',data=top_allrounders)
plt.ylabel('Wickets')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Wickets')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Wickets')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_allrounders)
plt.ylabel('Bowling Average')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Bowling Average')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Bowling Average')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Economy',data=top_allrounders,palette="rocket")
plt.ylabel('Economy')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Economy')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Economy')

# %%
sns.set(font_scale=1.1)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_allrounders)
plt.ylabel('Bowling Strike Rate')
sns.set(font_scale=1.5)
plt.title('Top All Rounders vs Bowling Strike Rate')
# Out:
# Text(0.5, 1.0, 'Top All Rounders vs Bowling Strike Rate')

# %% [markdown]
# # Visualization of Wicket Keepers Data:

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_keepers,palette='husl')
plt.ylabel('Matches Played')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Matches Played')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Matches Played')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Runs',data=top_keepers,palette='husl')
plt.ylabel('Runs')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Runs')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Runs')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Average',data=top_keepers,palette='husl')
plt.ylabel('Average')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Average')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Average')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_keepers,palette='husl')
plt.ylabel('Strike Rate')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Strike Rate')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Strike Rate')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Catches',data=top_keepers,palette='husl')
plt.ylabel('Catches')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Catches')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Catches')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Run_outs',data=top_keepers,palette='husl')
plt.ylabel('Run Outs')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Run Outs')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Run Outs')

# %%
sns.set(font_scale=1.3)
plt.figure(figsize = (20,10))
sns.barplot(x='Player Name',y='Stumps',data=top_keepers,palette='Paired')
plt.ylabel('Stumps')
sns.set(font_scale=1.5)
plt.title('Top Wicket Keepers vs Stumps')
# Out:
# Text(0.5, 1.0, 'Top Wicket Keepers vs Stumps')

# %% [markdown]
# The ratio of 11 players will be:
# 1. 3 Batters
# 2. 3 Allrounders
# 3. 4 Bowlers with 2 spin options
# 4. 1 Wicket Keeper

# %%
# Batters for the final 11 will be- KL Rahul, David Warner, Virat Kohli
top_batters.reset_index(drop=True)
matches_value=[top_batters.iloc[6]['Matches_Played'],top_batters.iloc[2]['Matches_Played'],top_batters.iloc[5]['Matches_Played']]
runs_values=[top_batters.iloc[6]['Runs'],top_batters.iloc[2]['Runs'],top_batters.iloc[5]['Runs']]
average_values=[top_batters.iloc[6]['Average'],top_batters.iloc[2]['Average'],top_batters.iloc[5]['Average']]
strike_value=[top_batters.iloc[6]['Strike_Rate'],top_batters.iloc[2]['Strike_Rate'],top_batters.iloc[5]['Strike_Rate']]

labels=['KL Rahul', 'David Warner', 'Virat Kohli']
fig, axes = plt.subplots(2,2, figsize=(20,20))
sns.set(font_scale=1.3)
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL career")
axes[1][0].set_title("Average")
axes[1][1].set_title("Strike Rate")
sns.set(font_scale=1)
sns.barplot(x=labels, y=matches_value, ax=axes[0][0],palette='husl')
sns.barplot(x=labels, y=runs_values, ax=axes[0][1],palette='husl')
sns.barplot(x=labels, y=average_values, ax=axes[1][0],palette='husl')
sns.barplot(x=labels, y=strike_value, ax=axes[1][1],palette='husl')
# Out:
# <AxesSubplot:title={'center':'Strike Rate'}>

# %%
# all rounders for the final 11 will be - Andre Russel, Hardik Pandya, Sunil Narine
top_allrounders.reset_index(drop=True)
matches_value=[top_allrounders.iloc[5]['Matches_Played'],top_allrounders.iloc[6]['Matches_Played'],top_allrounders.iloc[9]['Matches_Played']]
runs_value=[top_allrounders.iloc[5]['Runs'],top_allrounders.iloc[6]['Runs'],top_allrounders.iloc[9]['Runs']]
average_value=[top_allrounders.iloc[5]['Average'],top_allrounders.iloc[6]['Average'],top_allrounders.iloc[9]['Average']]
strike_rate_value=[top_allrounders.iloc[5]['Strike_Rate'],top_allrounders.iloc[6]['Strike_Rate'],top_allrounders.iloc[9]['Strike_Rate']]
wicket_value=[top_allrounders.iloc[5]['Wickets'],top_allrounders.iloc[6]['Wickets'],top_allrounders.iloc[9]['Wickets']]
bowling_average_value=[top_allrounders.iloc[5]['Bowling_average'],top_allrounders.iloc[6]['Bowling_average'],top_allrounders.iloc[9]['Bowling_average']]
economy_value=[top_allrounders.iloc[5]['Economy'],top_allrounders.iloc[6]['Economy'],top_allrounders.iloc[9]['Economy']]
bowling_strike_rate_value=[top_allrounders.iloc[5]['Bowling_Strike_Rate'],top_allrounders.iloc[6]['Bowling_Strike_Rate'],top_allrounders.iloc[9]['Bowling_Strike_Rate']]

labels=['Andre Russel', 'Hardik Pandya', 'Sunil Narine']

fig, axes = plt.subplots(4,2,figsize=(20,20))
sns.set(font_scale=1.3)
axes[0][0].set_title('Matches')
axes[0][1].set_title('Runs')
axes[1][0].set_title('Average')
axes[1][1].set_title('Strike Rate')
axes[2][0].set_title('Wickets')
axes[2][1].set_title('Bowling Average')
axes[3][0].set_title('Economy')
axes[3][1].set_title('Bowling Strike Rate')
sns.set(font_scale=1)

sns.barplot(x=labels, y=matches_value, ax=axes[0][0],palette='Paired')
sns.barplot(x=labels, y=runs_value, ax=axes[0][1],palette='Paired')
sns.barplot(x=labels, y=average_value, ax=axes[1][0],palette='Paired')
sns.barplot(x=labels, y=strike_rate_value, ax=axes[1][1],palette='Paired')
sns.barplot(x=labels, y=wicket_value, ax=axes[2][0],palette='Paired')
sns.barplot(x=labels, y=bowling_average_value, ax=axes[2][1],palette='Paired')
sns.barplot(x=labels, y=economy_value, ax=axes[3][0],palette='Paired')
sns.barplot(x=labels, y=bowling_strike_rate_value, ax=axes[3][1],palette='Paired')
# Out:
# <AxesSubplot:title={'center':'Bowling Strike Rate'}>

# %%
# Bowlers for the final 11 - Jasprit Bumbra, Kagiso Rabada, Nathan Coulter-Nile, Yuzvendra Chahal

top_bowlers.reset_index(drop=True)
matches_values=[top_bowlers.iloc[10]['Matches_Played'],top_bowlers.iloc[0]['Matches_Played'],top_bowlers.iloc[7]['Matches_Played'],top_bowlers.iloc[1]['Matches_Played']]
wickets_values=[top_bowlers.iloc[10]['Wickets'],top_bowlers.iloc[0]['Wickets'],top_bowlers.iloc[7]['Wickets'],top_bowlers.iloc[1]['Wickets']]
bowling_average_values=[top_bowlers.iloc[10]['Bowling_average'],top_bowlers.iloc[0]['Bowling_average'],top_bowlers.iloc[7]['Bowling_average'],top_bowlers.iloc[1]['Bowling_average']]
economy_values=[top_bowlers.iloc[10]['Economy'],top_bowlers.iloc[0]['Economy'],top_bowlers.iloc[7]['Economy'],top_bowlers.iloc[1]['Economy']]
bowling_strike_rate_Values=[top_bowlers.iloc[10]['Bowling_Strike_Rate'],top_bowlers.iloc[0]['Bowling_Strike_Rate'],top_bowlers.iloc[7]['Bowling_Strike_Rate'],top_bowlers.iloc[1]['Bowling_Strike_Rate']]

sns.set(font_scale=1.3)
fig, axes=plt.subplots(3,2, figsize=(20,20))
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Wickets")
axes[1][0].set_title("Bowling Average")
axes[1][1].set_title("Economy")
axes[2][0].set_title("Bowling Strike Rate")
names=['Jasprit Bumrah','Kagiso Rabada', 'Nathan Coulter-Nile', 'Yuzvendra Chahal']
sns.set(font_scale=0.8)

sns.barplot(x=names,y=matches_values, ax=axes[0][0], palette="Paired")
sns.barplot(x=names,y=wickets_values, ax=axes[0][1], palette="Paired")
sns.barplot(x=names,y=bowling_average_values, ax=axes[1][0], palette="Paired")
sns.barplot(x=names,y=economy_values, ax=axes[1][1], palette="Paired")
sns.barplot(x=names,y=bowling_strike_rate_Values, ax=axes[2][0], palette="Paired")
# Out:
# <AxesSubplot:title={'center':'Bowling Strike Rate'}>

# %%
batter1=top_batters.loc[(top_batters['Player Name']=='KL Rahul ')]
batter2=top_batters.loc[(top_batters['Player Name']=='David Warner ')]
batter3=top_batters.loc[(top_batters['Player Name']=='Virat Kohli')]

bowler1=top_bowlers.loc[(top_bowlers['Player Name']=='Jasprit Bumrah')]
bowler2=top_bowlers.loc[(top_bowlers['Player Name']=='Yuzvendra Chahal ')]
bowler3=top_bowlers.loc[(top_bowlers['Player Name']=='Kagiso Rabada ')]
bowler4=top_bowlers.loc[(top_bowlers['Player Name']=='Nathan Coulter-Nile')]

allrounder1=top_allrounders.loc[(top_allrounders['Player Name']=='Andre Russell')]
allrounder2=top_allrounders.loc[(top_allrounders['Player Name']=='Hardik Pandya')]
allrounder3=top_allrounders.loc[(top_allrounders['Player Name']=='Sunil Narine ')]

keeper=top_keepers.loc[(top_keepers['Player Name']=='MS Dhoni')]

# %% [markdown]
# The final 11 according to my analysis would be:

# %%
final=[batter1,batter2,batter3,keeper,allrounder1,allrounder2,allrounder3,bowler1,bowler2,bowler3,bowler4]
final_team=pd.concat(final)
final_team=final_team.drop(labels=['Matches_Played','Runs','Average','Strike_Rate', 'Catches','Run_outs','Stumps','Wickets','Bowling_average','Economy','Bowling_Strike_Rate'],axis=1)
final_team.reset_index(drop=True)
# Out:
#             Player Name       Team Nationality
# 0             KL Rahul     Lucknow      Indian
# 1         David Warner       Delhi    Overseas
# 2           Virat Kohli  Bangalore      Indian
# 3              MS Dhoni    Chennai      Indian
# 4         Andre Russell    Kolkata    Overseas
# 5         Hardik Pandya    Gujarat      Indian
# 6         Sunil Narine     Kolkata    Overseas
# 7        Jasprit Bumrah     Mumbai      Indian
# 8     Yuzvendra Chahal   Rajasthan      Indian
# 9        Kagiso Rabada      Punjab    Overseas
# 10  Nathan Coulter-Nile  Rajasthan    Overseas
